# %% [markdown]
# <a href="https://colab.research.google.com/github/adenugroho/Mchn-Learning/blob/main/Praktikum_1_Machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_excel('/content/drive/MyDrive/Kuliah 23/Semester 3/Machine Learning/final_grades.xlsx')
data2 = pd.read_excel('/content/drive/MyDrive/Kuliah 23/Semester 3/Machine Learning/intermediate_grades.xlsx')

# checking the shapes of the data
print("Shape of Final Grades data :", data1.shape)
print("Shape of Intermediate Grades data :",data2.shape)
# Out:
# Shape of Final Grades data : (52, 18)
# Shape of Intermediate Grades data : (115, 6)
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
data1.columns
# Out:
# Index(['Student ID', 'ES 1.1 \n(2 points)', 'ES 1.2 \n(3 points)',
#        'ES 2.1\n(2 points)', 'ES 2.2\n(3 points)', 'ES 3.1\n(1 points)',
#        'ES 3.2\n(2 points)', 'ES 3.3\n(2 points)', 'ES 3.4\n(2 points)',
#        'ES 3.5\n(3 points)', 'ES 4.1\n(15 points)', 'ES 4.2\n(10 points)',
#        'ES 5.1\n(2 points)', 'ES 5.2\n(10 points)', 'ES 5.3\n(3 points)',
#        'ES 6.1\n(25 points)', 'ES 6.2\n(15 points)', 'TOTAL\n(100 points)'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['Student Id', 'Session 2', 'Session 3', 'Session 4', 'Session 5',
#        'Session 6'],
#       dtype='object')

# %%
data1.head()
# Out:
#    Student ID  ES 1.1 \n(2 points)  ES 1.2 \n(3 points)  ES 2.1\n(2 points)  \
# 0           3                  2.0                    3                 1.0
# 1           6                  2.0                    3                 2.0
# 2           7                  2.0                    3                 1.0
# 3          10                  2.0                    3                 2.0
# 4          13                  2.0                    3                 2.0
#
#    ES 2.2\n(3 points)  ES 3.1\n(1 points)  ES 3.2\n(2 points)  \
# 0                 2.0                   1                   2
# 1                 3.0                   1                   2
# 2                 1.5                   1                   2
# 3                 1.5                   1                   2
# 4                 1.5                   1                   2
#
#    ES 3.3\n(2 points)  ES 3.4\n(2 points)  ES 3.5\n(3 points)  \
# 0                   2                 2.0                 3.0
# ...

# %%
data2.head()
# Out:
#    Student Id  Session 2  Session 3  Session 4  Session 5  Session 6
# 0           1        5.0        0.0        4.5        4.0       2.25
# 1           2        4.0        3.5        4.5        4.0       1.00
# 2           3        3.5        3.5        4.5        4.0       0.00
# 3           4        6.0        4.0        5.0        3.5       2.75
# 4           5        5.0        4.0        5.0        4.0       2.75

# %%
data1.describe()
# Out:
#        Student ID  ES 1.1 \n(2 points)  ES 1.2 \n(3 points)  \
# count   52.000000            52.000000            52.000000
# mean    55.538462             1.884615             2.865385
# std     30.733811             0.351682             0.595040
# min      3.000000             0.000000             0.000000
# 25%     28.750000             2.000000             3.000000
# 50%     57.500000             2.000000             3.000000
# 75%     83.500000             2.000000             3.000000
# max    106.000000             2.000000             3.000000
#
#        ES 2.1\n(2 points)  ES 2.2\n(3 points)  ES 3.1\n(1 points)  \
# count           52.000000           52.000000           52.000000
# mean             1.432692            1.259615            0.942308
# std              0.569045            1.077808            0.235435
# min              0.000000            0.000000            0.000000
# 25%              1.000000            0.000000            1.000000
# ...

# %%
data2.head()
# Out:
#    Student Id  Session 2  Session 3  Session 4  Session 5  Session 6
# 0           1        5.0        0.0        4.5        4.0       2.25
# 1           2        4.0        3.5        4.5        4.0       1.00
# 2           3        3.5        3.5        4.5        4.0       0.00
# 3           4        6.0        4.0        5.0        3.5       2.75
# 4           5        5.0        4.0        5.0        4.0       2.75

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Student ID          52 non-null     int64
#  1   ES 1.1
# (2 points)  52 non-null     float64
#  2   ES 1.2
# (3 points)  52 non-null     int64
#  3   ES 2.1
# (2 points)   52 non-null     float64
#  4   ES 2.2
# (3 points)   52 non-null     float64
#  5   ES 3.1
# (1 points)   52 non-null     int64
#  6   ES 3.2
# (2 points)   52 non-null     int64
#  7   ES 3.3
# (2 points)   52 non-null     int64
#  8   ES 3.4
# (2 points)   52 non-null     float64
#  9   ES 3.5
# (3 points)   52 non-null     float64
#  10  ES 4.1
# (15 points)  52 non-null     float64
#  11  ES 4.2
# (10 points)  52 non-null     float64
#  12  ES 5.1
# (2 points)   52 non-null     int64
#  13  ES 5.2
# (10 points)  52 non-null     float64
#  14  ES 5.3
# (3 points)   52 non-null     float64
#  15  ES 6.1
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student Id  115 non-null    int64
#  1   Session 2   115 non-null    float64
#  2   Session 3   115 non-null    float64
#  3   Session 4   115 non-null    float64
#  4   Session 5   115 non-null    float64
#  5   Session 6   115 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 5.5 KB

# %%
data1.isnull().sum()
# Out:
# Student ID             0
# ES 1.1 \n(2 points)    0
# ES 1.2 \n(3 points)    0
# ES 2.1\n(2 points)     0
# ES 2.2\n(3 points)     0
# ES 3.1\n(1 points)     0
# ES 3.2\n(2 points)     0
# ES 3.3\n(2 points)     0
# ES 3.4\n(2 points)     0
# ES 3.5\n(3 points)     0
# ES 4.1\n(15 points)    0
# ES 4.2\n(10 points)    0
# ES 5.1\n(2 points)     0
# ES 5.2\n(10 points)    0
# ES 5.3\n(3 points)     0
# ES 6.1\n(25 points)    0
# ES 6.2\n(15 points)    0
# TOTAL\n(100 points)    0
# dtype: int64

# %%
data2.isnull().sum()
# Out:
# Student Id    0
# Session 2     0
# Session 3     0
# Session 4     0
# Session 5     0
# Session 6     0
# dtype: int64

# %%
data1.dtypes
# Out:
# Student ID               int64
# ES 1.1 \n(2 points)    float64
# ES 1.2 \n(3 points)      int64
# ES 2.1\n(2 points)     float64
# ES 2.2\n(3 points)     float64
# ES 3.1\n(1 points)       int64
# ES 3.2\n(2 points)       int64
# ES 3.3\n(2 points)       int64
# ES 3.4\n(2 points)     float64
# ES 3.5\n(3 points)     float64
# ES 4.1\n(15 points)    float64
# ES 4.2\n(10 points)    float64
# ES 5.1\n(2 points)       int64
# ES 5.2\n(10 points)    float64
# ES 5.3\n(3 points)     float64
# ES 6.1\n(25 points)    float64
# ES 6.2\n(15 points)      int64
# TOTAL\n(100 points)    float64
# dtype: object

# %%
data2.dtypes
# Out:
# Student Id      int64
# Session 2     float64
# Session 3     float64
# Session 4     float64
# Session 5     float64
# Session 6     float64
# dtype: object

# %%
# making a heatmap  of the final grades data

plt.rcParams['figure.figsize'] = (15, 15)
sns.heatmap(data1, annot = True)
plt.title('Heatmap for the Final Grades Data',fontsize = 30)
plt.show()
